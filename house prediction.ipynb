# %% [markdown]
# # House Predcition

# %% [markdown]
# # Step 1= Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Step2= Load Dataset

# %%
da=pd.read_csv("C:\\Users\\Dell\\OneDrive\\Desktop\\jup\\new project house prediction\\house_price_prediction_dataset.csv")
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      1000 non-null   int64
#  1   Number of Bedrooms       1000 non-null   int64
#  2   Number of Bathrooms      1000 non-null   int64
#  3   Year Built               1000 non-null   int64
#  4   Number of Floors         1000 non-null   int64
#  5   Distance to City Center  1000 non-null   float64
#  6   Age of House             1000 non-null   int64
#  7   House Price              1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %% [markdown]
# # Step 3: Data Visualisation

# %%
import seaborn as sns

# %%
sns.pairplot(da)

# %% [markdown]
# # Step 4: Seperate input and output in different variables

# %%
x = da.iloc[:,0:7]
x
# Out:
#      Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                   1360                   2                    1        1931
# 1                   4272                   3                    3        1966
# 2                   3592                   1                    2        1966
# 3                    966                   1                    2        1927
# 4                   4926                   2                    1        1943
# ..                   ...                 ...                  ...         ...
# 995                 3261                   4                    1        1952
# 996                 3179                   1                    2        2019
# 997                 2606                   4                    2        2015
# 998                 4723                   5                    2        1922
# 999                 3268                   4                    2        2008
#
# ...

# %%
y = da.iloc[:,-1]
y
# Out:
# 0       18589.261072
# 1      216574.894902
# 2      156828.849255
# 3       22953.978863
# 4      208444.870562
#            ...
# 995    175486.089126
# 996    118042.115490
# 997    260338.235848
# 998    209617.887250
# 999    118241.299863
# Name: House Price, Length: 1000, dtype: float64

# %% [markdown]
# # Step5:Split input output data in training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 29 to 102
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      800 non-null    int64
#  1   Number of Bedrooms       800 non-null    int64
#  2   Number of Bathrooms      800 non-null    int64
#  3   Year Built               800 non-null    int64
#  4   Number of Floors         800 non-null    int64
#  5   Distance to City Center  800 non-null    float64
#  6   Age of House             800 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 50.0 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 521 to 78
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      200 non-null    int64
#  1   Number of Bedrooms       200 non-null    int64
#  2   Number of Bathrooms      200 non-null    int64
#  3   Year Built               200 non-null    int64
#  4   Number of Floors         200 non-null    int64
#  5   Distance to City Center  200 non-null    float64
#  6   Age of House             200 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 12.5 KB

# %%
 y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 800 entries, 29 to 102
# Series name: House Price
# Non-Null Count  Dtype
# --------------  -----
# 800 non-null    float64
# dtypes: float64(1)
# memory usage: 12.5 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 200 entries, 521 to 78
# Series name: House Price
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    float64
# dtypes: float64(1)
# memory usage: 3.1 KB

# %% [markdown]
# # Step 6: Import Algorithm

# %%
from sklearn.linear_model import LinearRegression
ho = LinearRegression()

# %% [markdown]
# # Step 7: Model Train(.fit()) and Prediction(.predict())

# %%
ho.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ho.predict(x_test)

# %%
da.head(2)
# Out:
#    Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                 1360                   2                    1        1931
# 1                 4272                   3                    3        1966
#
#    Number of Floors  Distance to City Center  Age of House    House Price
# 0                 1                21.598000            94   18589.261072
# 1                 3                 8.816612            59  216574.894902

# %% [markdown]
# # accuracy

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6993330083847774
